# %%
a = list[1,2,3]
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-479861334524> in <module>()
# ----> 1 a = list[1,2,3]
#       2 a
#
# TypeError: 'type' object has no attribute '__getitem__'

# %%
a = list[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-72c2bfa998d7> in <module>()
# ----> 1 a = list[1,2,3]
#
# TypeError: 'type' object has no attribute '__getitem__'

# %%
a = 10

# %%
print a
# Out:
# 10

# %%
import numpy as np
import pandas as pd
print 'Hello World'
# Out:
# Hello World

# %%
tips = pd.read_csv('c:\workPy\tips.csv')
tips.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-d63d790d8085> in <module>()
# ----> 1 tips = pd.read_csv('c:\workPy\tips.csv')
#       2 tips.head()
#
# ...

# %%
img = plt.imread('c:\workPy\sinkbug.png')
fiture(figsize=4,4)
plt.imshow(img)
# Out:
#   File "<ipython-input-7-23452f6692ab>", line 2
#     fiture(figsize=4,4)
# SyntaxError: non-keyword arg after keyword arg

# %%
img = plt.imread('c:\workPy\sinkbug.png')
figure(figsize=(4,4))
plt.imshow(img)
# Out:
#   File "<ipython-input-8-1ddf8c7e95f9>", line 2
#     figure(figsize=4,4)
# SyntaxError: non-keyword arg after keyword arg

# %%
img = plt.imread('c:\workPy\sinkbug.png')
figure(figsize=(4,4))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-cbc72793d3d1> in <module>()
# ----> 1 img = plt.imread('c:\workPy\sinkbug.png')
#       2 figure(figsize=(4,4))
#       3 plt.imshow(img)
#
# C:\Users\papasmf1\AppData\Local\Enthought\Canopy32\User\lib\site-packages\matplotlib\pyplot.pyc in imread(*args, **kwargs)
#    2175 @docstring.copy_dedent(_imread)
#    2176 def imread(*args, **kwargs):
# -> 2177     return _imread(*args, **kwargs)
#    2178
#    2179
#
# C:\Users\papasmf1\AppData\Local\Enthought\Canopy32\User\lib\site-packages\matplotlib\image.pyc in imread(fname, format)
#    1253     # tricky in C.
#    1254     if cbook.is_string_like(fname):
# -> 1255         with open(fname, 'rb') as fd:
#    1256             return handler(fd)
#    1257     else:
#
# IOError: [Errno 2] No such file or directory: 'c:\\workPy\\sinkbug.png'

# %%
img = plt.imread('c:\workPy\stinkbug.png')
figure(figsize=(4,4))
plt.imshow(img)

# %%
import numpy as np
import pandas as pd
print 'Hello World'
# Out:
# Hello World

# %%
img = plt.imread('c:\workPy\stinkbug.png')
figure(figsize=(4,4))
plt.imshow(img)
